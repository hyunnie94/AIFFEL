# %% [markdown]
# # 20-13. 프로젝트 : Segmentation map으로 도로 이미지 만들기
#
# ### [루브릭]
# 1. pix2pix 모델 학습을 위해 필요한 데이터셋을 적절히 구축하였다.
#     - 데이터 분석 과정 및 한 가지 이상의 augmentation을 포함한 데이터셋 구축 과정이 체계적으로 제시되었다.
#
#
# 2. pix2pix 모델을 구현하여 성공적으로 학습 과정을 진행하였다.
#     - U-Net generator, discriminator 모델 구현이 완료되어 train_step이 안정적으로 진행됨을 확인하였다.
#
#
# 3. 학습 과정 및 테스트에 대한 시각화 결과를 제출하였다.
#     - 10 epoch 이상의 학습을 진행한 후 최종 테스트 결과에서 진행한 epoch 수에 걸맞은 정도의 품질을 확인하였다.
#
# ### [학습 과정]
# 1. 데이터에 한 가지 이상의 augmentation 방법을 적용하여 학습해주세요.
# (어떠한 방법을 사용했는지 적어주세요.)
# 2. 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 U-Net Generator를 사용해주세요.
# 3. 모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운받았던 "val" 폴더 내 이미지를 사용해주세요.
# 4. 1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를 스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화해 주세요.
# 5. 모델을 충분히 학습하기에 시간이 부족할 수 있습니다. 적어도 10 epoch 이상 학습하며 중간 손실 값에 대한 로그를 남겨주세요. 좋은 결과를 얻기 위해선 긴 학습 시간이 필요하므로 테스트 결과는 만족스럽지 않아도 괜찮습니다.
#
# ### [결론 및 회고]

# %%
import os

data_path = os.getenv('HOME')+'/aiffel/E20_conditionalGAN/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
# 이미지 하나 열어 크기 확인

f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
# (256, 256, 3) 크기의 2개의 이미지로 분할해서 사용합니다.

import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %% [markdown]
# ## Data augmentation

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])      # 크롭!
    
    out = image.random_flip_left_right(out)                  # 좌우반전!
    out = image.random_flip_up_down(out)                     # 상하반전!
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)        # 90도 회전!
    
    return out[...,:3], out[...,3:]

# %%
# augmentation 적용 후 시각화

plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block (EncodeBlock)      (None, 128, 128, 64) 3072        input_1[0][0]
# __________________________________________________________________________________________________
# encode_block_1 (EncodeBlock)    (None, 64, 64, 128)  131584      encode_block[0][0]
# __________________________________________________________________________________________________
# encode_block_2 (EncodeBlock)    (None, 32, 32, 256)  525312      encode_block_1[0][0]
# __________________________________________________________________________________________________
# encode_block_3 (EncodeBlock)    (None, 16, 16, 512)  2099200     encode_block_2[0][0]
# __________________________________________________________________________________________________
# encode_block_4 (EncodeBlock)    (None, 8, 8, 512)    4196352     encode_block_3[0][0]
# __________________________________________________________________________________________________
# encode_block_5 (EncodeBlock)    (None, 4, 4, 512)    4196352     encode_block_4[0][0]
# __________________________________________________________________________________________________
# encode_block_6 (EncodeBlock)    (None, 2, 2, 512)    4196352     encode_block_5[0][0]
# __________________________________________________________________________________________________
# encode_block_7 (EncodeBlock)    (None, 1, 1, 512)    4196352     encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 2, 2, 512)    4196352     encode_block_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block[0][0]
#                                                                  encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_1[0][0]
#                                                                  encode_block_5[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_2[0][0]
#                                                                  encode_block_4[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_3[0][0]
#                                                                  encode_block_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_4[0][0]
#                                                                  encode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_5 (DecodeBlock)    (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_5[0][0]
#                                                                  encode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_6 (DecodeBlock)    (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_6[0][0]
#                                                                  encode_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 200

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 20회 반복마다 손실을 출력합니다.
        if (i+1) % 100 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[100]
# Generator_loss:1.9350
# L1_loss:0.2271
# Discriminator_loss:0.6385
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.3758
# L1_loss:0.2167
# Discriminator_loss:0.5829
#
# EPOCH[2] - STEP[100]
# Generator_loss:0.7091
# L1_loss:0.1819
# Discriminator_loss:0.8693
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.5555
# L1_loss:0.2215
# Discriminator_loss:0.6663
#
# EPOCH[3] - STEP[100]
# Generator_loss:2.3356
# L1_loss:0.1933
# Discriminator_loss:0.9382
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.6373
# L1_loss:0.2037
# Discriminator_loss:0.4256
#
# EPOCH[4] - STEP[100]
# Generator_loss:0.5981
# L1_loss:0.1956
# Discriminator_loss:1.1993
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.8294
# L1_loss:0.1815
# Discriminator_loss:0.2929
#
# EPOCH[5] - STEP[100]
# Generator_loss:2.8112
# L1_loss:0.1899
# Discriminator_loss:0.7549
#
# EPOCH[5] - STEP[200]
# Generator_loss:2.0101
# L1_loss:0.2025
# Discriminator_loss:0.4690
#
# EPOCH[6] - STEP[100]
# Generator_loss:0.4842
# L1_loss:0.1687
# Discriminator_loss:1.2310
#
# EPOCH[6] - STEP[200]
# Generator_loss:0.7065
# L1_loss:0.1905
# Discriminator_loss:1.0682
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.2593
# L1_loss:0.1917
# Discriminator_loss:0.5312
#
# EPOCH[7] - STEP[200]
# Generator_loss:0.6672
# L1_loss:0.2137
# Discriminator_loss:0.9483
#
# EPOCH[8] - STEP[100]
# Generator_loss:3.0600
# L1_loss:0.1467
# Discriminator_loss:0.6107
#
# EPOCH[8] - STEP[200]
# Generator_loss:2.4121
# L1_loss:0.1688
# Discriminator_loss:0.3750
#
# EPOCH[9] - STEP[100]
# Generator_loss:1.6754
# L1_loss:0.1680
# Discriminator_loss:0.5100
#
# EPOCH[9] - STEP[200]
# Generator_loss:2.9080
# L1_loss:0.1775
# Discriminator_loss:1.2146
#
# EPOCH[10] - STEP[100]
# Generator_loss:2.3429
# L1_loss:0.1628
# Discriminator_loss:0.8516
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.7260
# L1_loss:0.1572
# Discriminator_loss:1.0250
#
# EPOCH[11] - STEP[100]
# Generator_loss:1.3726
# L1_loss:0.1365
# Discriminator_loss:0.7222
#
# EPOCH[11] - STEP[200]
# Generator_loss:1.5719
# L1_loss:0.1794
# Discriminator_loss:0.6515
#
# EPOCH[12] - STEP[100]
# Generator_loss:2.3191
# L1_loss:0.2072
# Discriminator_loss:0.6628
#
# EPOCH[12] - STEP[200]
# Generator_loss:1.6902
# L1_loss:0.1444
# Discriminator_loss:0.7513
#
# EPOCH[13] - STEP[100]
# Generator_loss:3.2119
# L1_loss:0.1779
# Discriminator_loss:1.2605
#
# EPOCH[13] - STEP[200]
# Generator_loss:0.8309
# L1_loss:0.1908
# Discriminator_loss:0.7888
#
# EPOCH[14] - STEP[100]
# Generator_loss:1.7472
# L1_loss:0.1574
# Discriminator_loss:0.4775
#
# EPOCH[14] - STEP[200]
# Generator_loss:2.7318
# L1_loss:0.1631
# Discriminator_loss:1.2033
#
# EPOCH[15] - STEP[100]
# Generator_loss:0.6356
# L1_loss:0.1748
# Discriminator_loss:1.0188
#
# EPOCH[15] - STEP[200]
# Generator_loss:2.0806
# L1_loss:0.1476
# Discriminator_loss:1.5131
#
# EPOCH[16] - STEP[100]
# Generator_loss:1.8573
# L1_loss:0.1398
# Discriminator_loss:0.4372
#
# EPOCH[16] - STEP[200]
# Generator_loss:0.7158
# L1_loss:0.1663
# Discriminator_loss:1.0626
#
# EPOCH[17] - STEP[100]
# Generator_loss:2.2251
# L1_loss:0.1407
# Discriminator_loss:0.4178
#
# EPOCH[17] - STEP[200]
# Generator_loss:1.4280
# L1_loss:0.1636
# Discriminator_loss:0.4526
#
# EPOCH[18] - STEP[100]
# Generator_loss:1.3930
# L1_loss:0.1586
# Discriminator_loss:0.4080
#
# EPOCH[18] - STEP[200]
# Generator_loss:0.6756
# L1_loss:0.1695
# Discriminator_loss:1.0141
#
# EPOCH[19] - STEP[100]
# Generator_loss:0.8356
# L1_loss:0.1423
# Discriminator_loss:0.9834
#
# EPOCH[19] - STEP[200]
# Generator_loss:1.5150
# L1_loss:0.1790
# Discriminator_loss:0.4848
#
# EPOCH[20] - STEP[100]
# Generator_loss:1.8135
# L1_loss:0.2223
# Discriminator_loss:1.0450
#
# EPOCH[20] - STEP[200]
# Generator_loss:1.2232
# L1_loss:0.1665
# Discriminator_loss:0.6210
#
# EPOCH[21] - STEP[100]
# Generator_loss:3.7342
# L1_loss:0.1731
# Discriminator_loss:0.5538
#
# EPOCH[21] - STEP[200]
# Generator_loss:2.1645
# L1_loss:0.1955
# Discriminator_loss:0.3260
#
# EPOCH[22] - STEP[100]
# Generator_loss:1.7437
# L1_loss:0.1701
# Discriminator_loss:0.3381
#
# EPOCH[22] - STEP[200]
# Generator_loss:3.3249
# L1_loss:0.1588
# Discriminator_loss:0.3662
#
# EPOCH[23] - STEP[100]
# Generator_loss:1.2106
# L1_loss:0.1856
# Discriminator_loss:0.6368
#
# EPOCH[23] - STEP[200]
# Generator_loss:2.2230
# L1_loss:0.2235
# Discriminator_loss:0.4406
#
# EPOCH[24] - STEP[100]
# Generator_loss:3.4878
# L1_loss:0.1253
# Discriminator_loss:0.9019
#
# EPOCH[24] - STEP[200]
# Generator_loss:2.4138
# L1_loss:0.1559
# Discriminator_loss:0.3376
#
# EPOCH[25] - STEP[100]
# Generator_loss:1.7693
# L1_loss:0.1538
# Discriminator_loss:0.5717
#
# EPOCH[25] - STEP[200]
# Generator_loss:2.4559
# L1_loss:0.1639
# Discriminator_loss:0.5163
#
# EPOCH[26] - STEP[100]
# Generator_loss:1.9016
# L1_loss:0.1568
# Discriminator_loss:0.6447
#
# EPOCH[26] - STEP[200]
# Generator_loss:3.1535
# L1_loss:0.1422
# Discriminator_loss:1.7129
#
# EPOCH[27] - STEP[100]
# Generator_loss:1.3958
# L1_loss:0.1467
# Discriminator_loss:0.5087
#
# EPOCH[27] - STEP[200]
# Generator_loss:2.3392
# L1_loss:0.1560
# Discriminator_loss:0.5009
#
# EPOCH[28] - STEP[100]
# Generator_loss:1.8495
# L1_loss:0.1498
# Discriminator_loss:0.8601
#
# EPOCH[28] - STEP[200]
# Generator_loss:0.9044
# L1_loss:0.1572
# Discriminator_loss:0.7307
# EPOCH[29] - STEP[100]
# Generator_loss:4.1121
# L1_loss:0.1519
# Discriminator_loss:1.1774
#
# EPOCH[29] - STEP[200]
# Generator_loss:2.0421
# L1_loss:0.1551
# Discriminator_loss:0.2510
#
# EPOCH[30] - STEP[100]
# Generator_loss:1.9755
# L1_loss:0.1547
# Discriminator_loss:0.4860
#
# EPOCH[30] - STEP[200]
# Generator_loss:0.1899
# L1_loss:0.1283
# Discriminator_loss:2.3642
#
# EPOCH[31] - STEP[100]
# Generator_loss:2.3714
# L1_loss:0.1496
# Discriminator_loss:0.3149
#
# EPOCH[31] - STEP[200]
# Generator_loss:1.4632
# L1_loss:0.2056
# Discriminator_loss:0.4199
#
# EPOCH[32] - STEP[100]
# Generator_loss:2.7083
# L1_loss:0.1484
# Discriminator_loss:0.4510
#
# EPOCH[32] - STEP[200]
# Generator_loss:2.8012
# L1_loss:0.1879
# Discriminator_loss:0.2319
#
# EPOCH[33] - STEP[100]
# Generator_loss:2.3895
# L1_loss:0.1778
# Discriminator_loss:0.1651
#
# EPOCH[33] - STEP[200]
# Generator_loss:2.6683
# L1_loss:0.1402
# Discriminator_loss:0.4490
#
# EPOCH[34] - STEP[100]
# Generator_loss:1.8399
# L1_loss:0.1556
# Discriminator_loss:0.3579
#
# EPOCH[34] - STEP[200]
# Generator_loss:2.9724
# L1_loss:0.1377
# Discriminator_loss:0.9092
#
# EPOCH[35] - STEP[100]
# Generator_loss:1.9532
# L1_loss:0.1731
# Discriminator_loss:0.4477
#
# EPOCH[35] - STEP[200]
# Generator_loss:2.4517
# L1_loss:0.1790
# Discriminator_loss:0.1717
#
# EPOCH[36] - STEP[100]
# Generator_loss:1.2833
# L1_loss:0.1628
# Discriminator_loss:0.8942
#
# EPOCH[36] - STEP[200]
# Generator_loss:1.7964
# L1_loss:0.1322
# Discriminator_loss:0.6051
#
# EPOCH[37] - STEP[100]
# Generator_loss:0.8552
# L1_loss:0.1751
# Discriminator_loss:0.8074
#
# EPOCH[37] - STEP[200]
# Generator_loss:3.1242
# L1_loss:0.1418
# Discriminator_loss:0.3773
#
# EPOCH[38] - STEP[100]
# Generator_loss:1.2334
# L1_loss:0.1643
# Discriminator_loss:0.6031
#
# EPOCH[38] - STEP[200]
# Generator_loss:2.2473
# L1_loss:0.1278
# Discriminator_loss:0.4798
#
# EPOCH[39] - STEP[100]
# Generator_loss:2.3433
# L1_loss:0.1657
# Discriminator_loss:0.2529
#
# EPOCH[39] - STEP[200]
# Generator_loss:1.7477
# L1_loss:0.1497
# Discriminator_loss:0.3812
#
# EPOCH[40] - STEP[100]
# Generator_loss:2.1448
# L1_loss:0.1494
# Discriminator_loss:0.5018
#
# EPOCH[40] - STEP[200]
# Generator_loss:1.9382
# L1_loss:0.1765
# Discriminator_loss:0.3656
#
# EPOCH[41] - STEP[100]
# Generator_loss:1.6929
# L1_loss:0.1368
# Discriminator_loss:0.4409
#
# EPOCH[41] - STEP[200]
# Generator_loss:2.2359
# L1_loss:0.1373
# Discriminator_loss:0.3179
#
# EPOCH[42] - STEP[100]
# Generator_loss:3.3458
# L1_loss:0.1488
# Discriminator_loss:0.5190
#
# EPOCH[42] - STEP[200]
# Generator_loss:2.4184
# L1_loss:0.1427
# Discriminator_loss:0.4751
#
# EPOCH[43] - STEP[100]
# Generator_loss:2.4732
# L1_loss:0.1633
# Discriminator_loss:0.2675
#
# EPOCH[43] - STEP[200]
# Generator_loss:1.0176
# L1_loss:0.1619
# Discriminator_loss:0.6848
#
# EPOCH[44] - STEP[100]
# Generator_loss:1.2378
# L1_loss:0.1809
# Discriminator_loss:0.5432
#
# EPOCH[44] - STEP[200]
# Generator_loss:3.9733
# L1_loss:0.1389
# Discriminator_loss:0.1385
#
# EPOCH[45] - STEP[100]
# Generator_loss:3.3158
# L1_loss:0.1642
# Discriminator_loss:0.3172
#
# EPOCH[45] - STEP[200]
# Generator_loss:2.5070
# L1_loss:0.1555
# Discriminator_loss:0.1655
#
# EPOCH[46] - STEP[100]
# Generator_loss:3.6724
# L1_loss:0.1486
# Discriminator_loss:0.2580
#
# EPOCH[46] - STEP[200]
# Generator_loss:3.0278
# L1_loss:0.1506
# Discriminator_loss:0.2011
#
# EPOCH[47] - STEP[100]
# Generator_loss:2.9440
# L1_loss:0.1459
# Discriminator_loss:0.2006
#
# EPOCH[47] - STEP[200]
# Generator_loss:2.6789
# L1_loss:0.1527
# Discriminator_loss:0.6496
#
# EPOCH[48] - STEP[100]
# Generator_loss:2.7822
# L1_loss:0.1288
# Discriminator_loss:0.3247
#
# EPOCH[48] - STEP[200]
# Generator_loss:1.1568
# L1_loss:0.1440
# Discriminator_loss:0.7386
#
# EPOCH[49] - STEP[100]
# Generator_loss:4.3966
# L1_loss:0.1445
# Discriminator_loss:0.2334
#
# EPOCH[49] - STEP[200]
# Generator_loss:2.3881
# L1_loss:0.1371
# Discriminator_loss:0.2875
#
# EPOCH[50] - STEP[100]
# Generator_loss:1.6053
# L1_loss:0.1424
# Discriminator_loss:0.3943
#
# EPOCH[50] - STEP[200]
# Generator_loss:2.0582
# L1_loss:0.1385
# Discriminator_loss:0.2351
#
# EPOCH[51] - STEP[100]
# Generator_loss:2.6129
# L1_loss:0.1302
# Discriminator_loss:0.2157
#
# EPOCH[51] - STEP[200]
# Generator_loss:4.2250
# L1_loss:0.1235
# Discriminator_loss:1.2455
#
# EPOCH[52] - STEP[100]
# Generator_loss:2.3804
# L1_loss:0.1143
# Discriminator_loss:0.4790
#
# EPOCH[52] - STEP[200]
# Generator_loss:4.0167
# L1_loss:0.1256
# Discriminator_loss:1.8367
#
# EPOCH[53] - STEP[100]
# Generator_loss:2.5709
# L1_loss:0.1425
# Discriminator_loss:0.1379
#
# EPOCH[53] - STEP[200]
# Generator_loss:3.1781
# L1_loss:0.1083
# Discriminator_loss:0.7906
#
# EPOCH[54] - STEP[100]
# Generator_loss:3.7581
# L1_loss:0.1198
# Discriminator_loss:2.2814
#
# EPOCH[54] - STEP[200]
# Generator_loss:2.7512
# L1_loss:0.1252
# Discriminator_loss:0.4282
#
# EPOCH[55] - STEP[100]
# Generator_loss:1.4956
# L1_loss:0.1247
# Discriminator_loss:0.6209
#
# EPOCH[55] - STEP[200]
# Generator_loss:2.1653
# L1_loss:0.1498
# Discriminator_loss:0.6938
#
# EPOCH[56] - STEP[100]
# Generator_loss:1.2433
# L1_loss:0.1448
# Discriminator_loss:0.4787
# EPOCH[56] - STEP[200]
# Generator_loss:2.1757
# L1_loss:0.1500
# Discriminator_loss:0.4026
#
# EPOCH[57] - STEP[100]
# Generator_loss:2.5743
# L1_loss:0.1561
# Discriminator_loss:0.3911
#
# EPOCH[57] - STEP[200]
# Generator_loss:0.9649
# L1_loss:0.1151
# Discriminator_loss:1.1561
#
# EPOCH[58] - STEP[100]
# Generator_loss:2.3516
# L1_loss:0.1204
# Discriminator_loss:0.4484
#
# EPOCH[58] - STEP[200]
# Generator_loss:3.1631
# L1_loss:0.1212
# Discriminator_loss:0.3713
#
# EPOCH[59] - STEP[100]
# Generator_loss:3.2450
# L1_loss:0.1288
# Discriminator_loss:1.6010
#
# EPOCH[59] - STEP[200]
# Generator_loss:2.5121
# L1_loss:0.1207
# Discriminator_loss:0.3263
#
# EPOCH[60] - STEP[100]
# Generator_loss:1.7442
# L1_loss:0.1565
# Discriminator_loss:0.4544
#
# EPOCH[60] - STEP[200]
# Generator_loss:3.4032
# L1_loss:0.1501
# Discriminator_loss:0.9730
#
# EPOCH[61] - STEP[100]
# Generator_loss:0.6366
# L1_loss:0.1493
# Discriminator_loss:1.0435
#
# EPOCH[61] - STEP[200]
# Generator_loss:2.7325
# L1_loss:0.1328
# Discriminator_loss:0.4322
#
# EPOCH[62] - STEP[100]
# Generator_loss:4.1259
# L1_loss:0.1560
# Discriminator_loss:0.0469
#
# EPOCH[62] - STEP[200]
# Generator_loss:2.2170
# L1_loss:0.1451
# Discriminator_loss:0.2928
#
# EPOCH[63] - STEP[100]
# Generator_loss:3.0310
# L1_loss:0.1501
# Discriminator_loss:0.3318
#
# EPOCH[63] - STEP[200]
# Generator_loss:5.3125
# L1_loss:0.1442
# Discriminator_loss:0.2029
#
# EPOCH[64] - STEP[100]
# Generator_loss:4.4147
# L1_loss:0.1284
# Discriminator_loss:0.1491
#
# EPOCH[64] - STEP[200]
# Generator_loss:1.3622
# L1_loss:0.1375
# Discriminator_loss:0.9419
#
# EPOCH[65] - STEP[100]
# Generator_loss:2.5053
# L1_loss:0.1161
# Discriminator_loss:0.2825
#
# EPOCH[65] - STEP[200]
# Generator_loss:3.1317
# L1_loss:0.1597
# Discriminator_loss:0.1170
#
# EPOCH[66] - STEP[100]
# Generator_loss:2.1965
# L1_loss:0.1295
# Discriminator_loss:0.5028
#
# EPOCH[66] - STEP[200]
# Generator_loss:5.6894
# L1_loss:0.1380
# Discriminator_loss:0.6470
#
# EPOCH[67] - STEP[100]
# Generator_loss:1.4853
# L1_loss:0.1238
# Discriminator_loss:0.4421
#
# EPOCH[67] - STEP[200]
# Generator_loss:5.5727
# L1_loss:0.1423
# Discriminator_loss:0.0281
#
# EPOCH[68] - STEP[100]
# Generator_loss:4.1669
# L1_loss:0.1290
# Discriminator_loss:0.4521
#
# EPOCH[68] - STEP[200]
# Generator_loss:1.2913
# L1_loss:0.1156
# Discriminator_loss:0.7730
#
# EPOCH[69] - STEP[100]
# Generator_loss:2.2468
# L1_loss:0.1563
# Discriminator_loss:0.4135
#
# EPOCH[69] - STEP[200]
# Generator_loss:3.1558
# L1_loss:0.1123
# Discriminator_loss:0.4772
#
# EPOCH[70] - STEP[100]
# Generator_loss:2.4764
# L1_loss:0.1400
# Discriminator_loss:0.3241
#
# EPOCH[70] - STEP[200]
# Generator_loss:2.8160
# L1_loss:0.1349
# Discriminator_loss:0.2586
#
# EPOCH[71] - STEP[100]
# Generator_loss:1.8021
# L1_loss:0.1574
# Discriminator_loss:0.3181
#
# EPOCH[71] - STEP[200]
# Generator_loss:4.5541
# L1_loss:0.1889
# Discriminator_loss:0.0237
#
# EPOCH[72] - STEP[100]
# Generator_loss:4.3553
# L1_loss:0.1193
# Discriminator_loss:1.3151
#
# EPOCH[72] - STEP[200]
# Generator_loss:2.9450
# L1_loss:0.1234
# Discriminator_loss:0.1403
#
# EPOCH[73] - STEP[100]
# Generator_loss:3.8916
# L1_loss:0.1346
# Discriminator_loss:0.1550
#
# EPOCH[73] - STEP[200]
# Generator_loss:2.6288
# L1_loss:0.1604
# Discriminator_loss:0.1966
#
# EPOCH[74] - STEP[100]
# Generator_loss:5.3997
# L1_loss:0.1156
# Discriminator_loss:0.0489
#
# EPOCH[74] - STEP[200]
# Generator_loss:4.8343
# L1_loss:0.1269
# Discriminator_loss:0.0847
#
# EPOCH[75] - STEP[100]
# Generator_loss:4.9283
# L1_loss:0.1339
# Discriminator_loss:0.2879
#
# EPOCH[75] - STEP[200]
# Generator_loss:0.7072
# L1_loss:0.1275
# Discriminator_loss:1.0361
#
# EPOCH[76] - STEP[100]
# Generator_loss:3.5453
# L1_loss:0.1642
# Discriminator_loss:0.1085
#
# EPOCH[76] - STEP[200]
# Generator_loss:4.8928
# L1_loss:0.1311
# Discriminator_loss:0.0411
#
# EPOCH[77] - STEP[100]
# Generator_loss:2.7728
# L1_loss:0.1280
# Discriminator_loss:0.1924
#
# EPOCH[77] - STEP[200]
# Generator_loss:1.0023
# L1_loss:0.1409
# Discriminator_loss:0.8482
#
# EPOCH[78] - STEP[100]
# Generator_loss:5.3769
# L1_loss:0.1136
# Discriminator_loss:1.2174
#
# EPOCH[78] - STEP[200]
# Generator_loss:3.4018
# L1_loss:0.1514
# Discriminator_loss:0.1567
#
# EPOCH[79] - STEP[100]
# Generator_loss:3.1142
# L1_loss:0.1409
# Discriminator_loss:0.2938
#
# EPOCH[79] - STEP[200]
# Generator_loss:1.1140
# L1_loss:0.1306
# Discriminator_loss:0.7114
#
# EPOCH[80] - STEP[100]
# Generator_loss:1.6967
# L1_loss:0.1500
# Discriminator_loss:0.3926
#
# EPOCH[80] - STEP[200]
# Generator_loss:3.8447
# L1_loss:0.1904
# Discriminator_loss:0.0518
#
# EPOCH[81] - STEP[100]
# Generator_loss:5.4931
# L1_loss:0.1844
# Discriminator_loss:0.0298
#
# EPOCH[81] - STEP[200]
# Generator_loss:3.4651
# L1_loss:0.1296
# Discriminator_loss:0.5168
#
# EPOCH[82] - STEP[100]
# Generator_loss:3.9367
# L1_loss:0.1376
# Discriminator_loss:0.1197
#
# EPOCH[82] - STEP[200]
# Generator_loss:2.6939
# L1_loss:0.1520
# Discriminator_loss:0.1356
#
# EPOCH[83] - STEP[100]
# Generator_loss:2.2122
# L1_loss:0.1375
# Discriminator_loss:0.2647
#
# EPOCH[83] - STEP[200]
# Generator_loss:5.9815
# L1_loss:0.1264
# Discriminator_loss:0.1030
# EPOCH[84] - STEP[100]
# Generator_loss:1.9237
# L1_loss:0.1253
# Discriminator_loss:0.3314
#
# EPOCH[84] - STEP[200]
# Generator_loss:2.6033
# L1_loss:0.1392
# Discriminator_loss:0.2977
#
# EPOCH[85] - STEP[100]
# Generator_loss:3.6739
# L1_loss:0.1269
# Discriminator_loss:0.2608
#
# EPOCH[85] - STEP[200]
# Generator_loss:4.6276
# L1_loss:0.1281
# Discriminator_loss:0.1298
#
# EPOCH[86] - STEP[100]
# Generator_loss:3.5012
# L1_loss:0.1496
# Discriminator_loss:0.1146
#
# EPOCH[86] - STEP[200]
# Generator_loss:2.9695
# L1_loss:0.1501
# Discriminator_loss:0.4722
#
# EPOCH[87] - STEP[100]
# Generator_loss:1.5986
# L1_loss:0.1406
# Discriminator_loss:0.7691
#
# EPOCH[87] - STEP[200]
# Generator_loss:6.6453
# L1_loss:0.1105
# Discriminator_loss:0.8399
#
# EPOCH[88] - STEP[100]
# Generator_loss:4.8594
# L1_loss:0.1251
# Discriminator_loss:0.1555
#
# EPOCH[88] - STEP[200]
# Generator_loss:2.4538
# L1_loss:0.1332
# Discriminator_loss:0.2171
#
# EPOCH[89] - STEP[100]
# Generator_loss:1.8116
# L1_loss:0.1018
# Discriminator_loss:0.2954
#
# EPOCH[89] - STEP[200]
# Generator_loss:4.5271
# L1_loss:0.1183
# Discriminator_loss:0.9981
#
# EPOCH[90] - STEP[100]
# Generator_loss:3.6867
# L1_loss:0.1495
# Discriminator_loss:0.0979
#
# EPOCH[90] - STEP[200]
# Generator_loss:3.6049
# L1_loss:0.1242
# Discriminator_loss:0.1382
#
# EPOCH[91] - STEP[100]
# Generator_loss:3.2987
# L1_loss:0.1673
# Discriminator_loss:0.1813
#
# EPOCH[91] - STEP[200]
# Generator_loss:5.6683
# L1_loss:0.1264
# Discriminator_loss:0.4919
#
# EPOCH[92] - STEP[100]
# Generator_loss:3.4508
# L1_loss:0.1465
# Discriminator_loss:0.1488
#
# EPOCH[92] - STEP[200]
# Generator_loss:3.0458
# L1_loss:0.1044
# Discriminator_loss:0.4233
#
# EPOCH[93] - STEP[100]
# Generator_loss:3.5250
# L1_loss:0.1441
# Discriminator_loss:0.0932
#
# EPOCH[93] - STEP[200]
# Generator_loss:6.2634
# L1_loss:0.1393
# Discriminator_loss:0.0936
#
# EPOCH[94] - STEP[100]
# Generator_loss:5.8493
# L1_loss:0.1245
# Discriminator_loss:0.0626
#
# EPOCH[94] - STEP[200]
# Generator_loss:3.9448
# L1_loss:0.1378
# Discriminator_loss:0.2571
#
# EPOCH[95] - STEP[100]
# Generator_loss:0.9031
# L1_loss:0.1340
# Discriminator_loss:1.1630
#
# EPOCH[95] - STEP[200]
# Generator_loss:3.2489
# L1_loss:0.1079
# Discriminator_loss:1.3175
#
# EPOCH[96] - STEP[100]
# Generator_loss:5.1804
# L1_loss:0.1408
# Discriminator_loss:0.1725
#
# EPOCH[96] - STEP[200]
# Generator_loss:1.7886
# L1_loss:0.1411
# Discriminator_loss:0.4087
#
# EPOCH[97] - STEP[100]
# Generator_loss:2.0623
# L1_loss:0.1431
# Discriminator_loss:0.2948
#
# EPOCH[97] - STEP[200]
# Generator_loss:2.2553
# L1_loss:0.1405
# Discriminator_loss:0.2736
#
# EPOCH[98] - STEP[100]
# Generator_loss:8.8057
# L1_loss:0.1351
# Discriminator_loss:2.3139
#
# EPOCH[98] - STEP[200]
# Generator_loss:3.6546
# L1_loss:0.1538
# Discriminator_loss:0.0813
#
# EPOCH[99] - STEP[100]
# Generator_loss:3.7384
# L1_loss:0.1662
# Discriminator_loss:0.0705
#
# EPOCH[99] - STEP[200]
# Generator_loss:3.2814
# L1_loss:0.1429
# Discriminator_loss:0.1525
#
# EPOCH[100] - STEP[100]
# Generator_loss:2.0069
# L1_loss:0.1319
# Discriminator_loss:0.2615
#
# EPOCH[100] - STEP[200]
# Generator_loss:3.1436
# L1_loss:0.1363
# Discriminator_loss:0.1017
#
# EPOCH[101] - STEP[100]
# Generator_loss:1.8546
# L1_loss:0.1148
# Discriminator_loss:0.9921
#
# EPOCH[101] - STEP[200]
# Generator_loss:3.0533
# L1_loss:0.1328
# Discriminator_loss:0.2936
#
# EPOCH[102] - STEP[100]
# Generator_loss:2.7330
# L1_loss:0.1635
# Discriminator_loss:0.2006
#
# EPOCH[102] - STEP[200]
# Generator_loss:5.6192
# L1_loss:0.1034
# Discriminator_loss:0.0639
#
# EPOCH[103] - STEP[100]
# Generator_loss:3.6192
# L1_loss:0.1244
# Discriminator_loss:0.1513
#
# EPOCH[103] - STEP[200]
# Generator_loss:1.5992
# L1_loss:0.1259
# Discriminator_loss:0.5487
#
# EPOCH[104] - STEP[100]
# Generator_loss:4.5773
# L1_loss:0.1286
# Discriminator_loss:0.5179
#
# EPOCH[104] - STEP[200]
# Generator_loss:3.1344
# L1_loss:0.1397
# Discriminator_loss:0.1729
#
# EPOCH[105] - STEP[100]
# Generator_loss:4.9111
# L1_loss:0.1375
# Discriminator_loss:0.0746
#
# EPOCH[105] - STEP[200]
# Generator_loss:6.0454
# L1_loss:0.1657
# Discriminator_loss:0.0191
#
# EPOCH[106] - STEP[100]
# Generator_loss:3.8277
# L1_loss:0.1424
# Discriminator_loss:0.7449
#
# EPOCH[106] - STEP[200]
# Generator_loss:3.4023
# L1_loss:0.1366
# Discriminator_loss:0.1697
#
# EPOCH[107] - STEP[100]
# Generator_loss:1.5493
# L1_loss:0.1187
# Discriminator_loss:0.6934
#
# EPOCH[107] - STEP[200]
# Generator_loss:4.0926
# L1_loss:0.1273
# Discriminator_loss:0.1805
#
# EPOCH[108] - STEP[100]
# Generator_loss:8.0245
# L1_loss:0.1694
# Discriminator_loss:0.4180
#
# EPOCH[108] - STEP[200]
# Generator_loss:4.9212
# L1_loss:0.1329
# Discriminator_loss:0.3944
#
# EPOCH[109] - STEP[100]
# Generator_loss:2.3229
# L1_loss:0.1236
# Discriminator_loss:3.0783
#
# EPOCH[109] - STEP[200]
# Generator_loss:3.2268
# L1_loss:0.1205
# Discriminator_loss:0.1277
#
# EPOCH[110] - STEP[100]
# Generator_loss:2.7483
# L1_loss:0.1185
# Discriminator_loss:0.2026
#
# EPOCH[110] - STEP[200]
# Generator_loss:3.9567
# L1_loss:0.1228
# Discriminator_loss:0.1124
#
# EPOCH[111] - STEP[100]
# Generator_loss:3.2709
# L1_loss:0.1269
# Discriminator_loss:0.0955
# EPOCH[111] - STEP[200]
# Generator_loss:2.9396
# L1_loss:0.1567
# Discriminator_loss:0.2910
#
# EPOCH[112] - STEP[100]
# Generator_loss:4.3091
# L1_loss:0.1252
# Discriminator_loss:0.0992
#
# EPOCH[112] - STEP[200]
# Generator_loss:5.6635
# L1_loss:0.1307
# Discriminator_loss:0.0581
#
# EPOCH[113] - STEP[100]
# Generator_loss:5.8161
# L1_loss:0.1355
# Discriminator_loss:0.2387
#
# EPOCH[113] - STEP[200]
# Generator_loss:1.6367
# L1_loss:0.1076
# Discriminator_loss:0.3641
#
# EPOCH[114] - STEP[100]
# Generator_loss:5.9690
# L1_loss:0.1423
# Discriminator_loss:0.0128
#
# EPOCH[114] - STEP[200]
# Generator_loss:1.9395
# L1_loss:0.1095
# Discriminator_loss:0.3452
#
# EPOCH[115] - STEP[100]
# Generator_loss:3.1166
# L1_loss:0.1213
# Discriminator_loss:0.2752
#
# EPOCH[115] - STEP[200]
# Generator_loss:2.2519
# L1_loss:0.1173
# Discriminator_loss:0.4040
#
# EPOCH[116] - STEP[100]
# Generator_loss:7.5829
# L1_loss:0.1467
# Discriminator_loss:0.3452
#
# EPOCH[116] - STEP[200]
# Generator_loss:2.3747
# L1_loss:0.1251
# Discriminator_loss:0.1955
#
# EPOCH[117] - STEP[100]
# Generator_loss:5.5476
# L1_loss:0.1140
# Discriminator_loss:1.4398
#
# EPOCH[117] - STEP[200]
# Generator_loss:4.7595
# L1_loss:0.1275
# Discriminator_loss:0.0225
#
# EPOCH[118] - STEP[100]
# Generator_loss:1.6833
# L1_loss:0.1068
# Discriminator_loss:0.7083
#
# EPOCH[118] - STEP[200]
# Generator_loss:3.4064
# L1_loss:0.1401
# Discriminator_loss:0.0616
#
# EPOCH[119] - STEP[100]
# Generator_loss:5.3645
# L1_loss:0.1773
# Discriminator_loss:0.0367
#
# EPOCH[119] - STEP[200]
# Generator_loss:2.4034
# L1_loss:0.1086
# Discriminator_loss:0.2435
#
# EPOCH[120] - STEP[100]
# Generator_loss:3.6194
# L1_loss:0.1224
# Discriminator_loss:0.0847
#
# EPOCH[120] - STEP[200]
# Generator_loss:3.3376
# L1_loss:0.1454
# Discriminator_loss:0.1602
#
# EPOCH[121] - STEP[100]
# Generator_loss:3.8572
# L1_loss:0.1707
# Discriminator_loss:0.1009
#
# EPOCH[121] - STEP[200]
# Generator_loss:4.2148
# L1_loss:0.1468
# Discriminator_loss:0.0547
#
# EPOCH[122] - STEP[100]
# Generator_loss:5.7907
# L1_loss:0.1302
# Discriminator_loss:0.2400
#
# EPOCH[122] - STEP[200]
# Generator_loss:5.1258
# L1_loss:0.1290
# Discriminator_loss:0.0208
#
# EPOCH[123] - STEP[100]
# Generator_loss:5.6928
# L1_loss:0.1242
# Discriminator_loss:0.1607
#
# EPOCH[123] - STEP[200]
# Generator_loss:0.9423
# L1_loss:0.1179
# Discriminator_loss:0.7320
#
# EPOCH[124] - STEP[100]
# Generator_loss:3.3017
# L1_loss:0.1070
# Discriminator_loss:0.1040
#
# EPOCH[124] - STEP[200]
# Generator_loss:3.4191
# L1_loss:0.1057
# Discriminator_loss:1.1743
#
# EPOCH[125] - STEP[100]
# Generator_loss:2.6653
# L1_loss:0.1023
# Discriminator_loss:0.1389
#
# EPOCH[125] - STEP[200]
# Generator_loss:3.2600
# L1_loss:0.1490
# Discriminator_loss:0.1026
#
# EPOCH[126] - STEP[100]
# Generator_loss:2.4134
# L1_loss:0.1486
# Discriminator_loss:0.2173
#
# EPOCH[126] - STEP[200]
# Generator_loss:4.9903
# L1_loss:0.1334
# Discriminator_loss:0.0802
#
# EPOCH[127] - STEP[100]
# Generator_loss:2.1574
# L1_loss:0.1586
# Discriminator_loss:0.2706
#
# EPOCH[127] - STEP[200]
# Generator_loss:4.6515
# L1_loss:0.1327
# Discriminator_loss:0.0481
#
# EPOCH[128] - STEP[100]
# Generator_loss:3.1108
# L1_loss:0.1305
# Discriminator_loss:0.1433
#
# EPOCH[128] - STEP[200]
# Generator_loss:5.4309
# L1_loss:0.1571
# Discriminator_loss:0.1742
#
# EPOCH[129] - STEP[100]
# Generator_loss:4.0591
# L1_loss:0.1208
# Discriminator_loss:0.2516
#
# EPOCH[129] - STEP[200]
# Generator_loss:2.6495
# L1_loss:0.1124
# Discriminator_loss:0.2185
#
# EPOCH[130] - STEP[100]
# Generator_loss:2.5379
# L1_loss:0.1183
# Discriminator_loss:0.2324
#
# EPOCH[130] - STEP[200]
# Generator_loss:3.6255
# L1_loss:0.1377
# Discriminator_loss:0.3656
#
# EPOCH[131] - STEP[100]
# Generator_loss:7.4713
# L1_loss:0.1323
# Discriminator_loss:0.1688
#
# EPOCH[131] - STEP[200]
# Generator_loss:3.7684
# L1_loss:0.1208
# Discriminator_loss:0.1011
#
# EPOCH[132] - STEP[100]
# Generator_loss:3.9556
# L1_loss:0.1536
# Discriminator_loss:0.1087
#
# EPOCH[132] - STEP[200]
# Generator_loss:5.5913
# L1_loss:0.1221
# Discriminator_loss:0.7311
#
# EPOCH[133] - STEP[100]
# Generator_loss:4.9552
# L1_loss:0.1105
# Discriminator_loss:1.1722
#
# EPOCH[133] - STEP[200]
# Generator_loss:4.8456
# L1_loss:0.1431
# Discriminator_loss:0.0315
#
# EPOCH[134] - STEP[100]
# Generator_loss:3.9254
# L1_loss:0.0993
# Discriminator_loss:0.2942
#
# EPOCH[134] - STEP[200]
# Generator_loss:2.3874
# L1_loss:0.1452
# Discriminator_loss:0.3045
#
# EPOCH[135] - STEP[100]
# Generator_loss:2.5438
# L1_loss:0.1025
# Discriminator_loss:0.1718
#
# EPOCH[135] - STEP[200]
# Generator_loss:2.9326
# L1_loss:0.1658
# Discriminator_loss:0.1228
#
# EPOCH[136] - STEP[100]
# Generator_loss:3.4208
# L1_loss:0.1052
# Discriminator_loss:0.0899
#
# EPOCH[136] - STEP[200]
# Generator_loss:3.7805
# L1_loss:0.1202
# Discriminator_loss:0.1378
#
# EPOCH[137] - STEP[100]
# Generator_loss:3.4451
# L1_loss:0.1482
# Discriminator_loss:0.1583
#
# EPOCH[137] - STEP[200]
# Generator_loss:6.3819
# L1_loss:0.1473
# Discriminator_loss:0.0668
#
# EPOCH[138] - STEP[100]
# Generator_loss:7.9073
# L1_loss:0.1263
# Discriminator_loss:0.3871
#
# EPOCH[138] - STEP[200]
# Generator_loss:6.0415
# L1_loss:0.1260
# Discriminator_loss:0.0373
# EPOCH[139] - STEP[100]
# Generator_loss:3.9666
# L1_loss:0.1183
# Discriminator_loss:0.1476
#
# EPOCH[139] - STEP[200]
# Generator_loss:5.3289
# L1_loss:0.1285
# Discriminator_loss:0.1098
#
# EPOCH[140] - STEP[100]
# Generator_loss:4.7788
# L1_loss:0.1202
# Discriminator_loss:0.0232
#
# EPOCH[140] - STEP[200]
# Generator_loss:4.3491
# L1_loss:0.1210
# Discriminator_loss:0.2680
#
# EPOCH[141] - STEP[100]
# Generator_loss:2.5356
# L1_loss:0.1270
# Discriminator_loss:0.2490
#
# EPOCH[141] - STEP[200]
# Generator_loss:3.2436
# L1_loss:0.1051
# Discriminator_loss:0.1477
#
# EPOCH[142] - STEP[100]
# Generator_loss:6.5187
# L1_loss:0.1294
# Discriminator_loss:0.0596
#
# EPOCH[142] - STEP[200]
# Generator_loss:1.4981
# L1_loss:0.1572
# Discriminator_loss:0.5378
#
# EPOCH[143] - STEP[100]
# Generator_loss:3.5217
# L1_loss:0.1123
# Discriminator_loss:0.0730
#
# EPOCH[143] - STEP[200]
# Generator_loss:5.6463
# L1_loss:0.1184
# Discriminator_loss:0.0317
#
# EPOCH[144] - STEP[100]
# Generator_loss:4.3363
# L1_loss:0.1300
# Discriminator_loss:0.0419
#
# EPOCH[144] - STEP[200]
# Generator_loss:4.1811
# L1_loss:0.1509
# Discriminator_loss:0.0423
#
# EPOCH[145] - STEP[100]
# Generator_loss:1.8580
# L1_loss:0.1155
# Discriminator_loss:0.3897
#
# EPOCH[145] - STEP[200]
# Generator_loss:3.5475
# L1_loss:0.1382
# Discriminator_loss:0.0774
#
# EPOCH[146] - STEP[100]
# Generator_loss:5.0381
# L1_loss:0.1230
# Discriminator_loss:0.0912
#
# EPOCH[146] - STEP[200]
# Generator_loss:4.0744
# L1_loss:0.1228
# Discriminator_loss:0.6586
#
# EPOCH[147] - STEP[100]
# Generator_loss:6.4061
# L1_loss:0.1083
# Discriminator_loss:0.3164
#
# EPOCH[147] - STEP[200]
# Generator_loss:2.3210
# L1_loss:0.1447
# Discriminator_loss:0.1959
#
# EPOCH[148] - STEP[100]
# Generator_loss:2.3972
# L1_loss:0.1727
# Discriminator_loss:0.1988
#
# EPOCH[148] - STEP[200]
# Generator_loss:5.4694
# L1_loss:0.1380
# Discriminator_loss:0.3384
#
# EPOCH[149] - STEP[100]
# Generator_loss:2.0491
# L1_loss:0.2108
# Discriminator_loss:0.3236
#
# EPOCH[149] - STEP[200]
# Generator_loss:2.9070
# L1_loss:0.1304
# Discriminator_loss:0.1919
#
# EPOCH[150] - STEP[100]
# Generator_loss:0.8081
# L1_loss:0.1131
# Discriminator_loss:1.1276
#
# EPOCH[150] - STEP[200]
# Generator_loss:4.9680
# L1_loss:0.1145
# Discriminator_loss:0.3534
#
# EPOCH[151] - STEP[100]
# Generator_loss:4.1712
# L1_loss:0.1399
# Discriminator_loss:0.0681
#
# EPOCH[151] - STEP[200]
# Generator_loss:4.8381
# L1_loss:0.1309
# Discriminator_loss:0.0197
#
# EPOCH[152] - STEP[100]
# Generator_loss:2.5605
# L1_loss:0.1407
# Discriminator_loss:0.3194
#
# EPOCH[152] - STEP[200]
# Generator_loss:7.9578
# L1_loss:0.1021
# Discriminator_loss:0.9475
#
# EPOCH[153] - STEP[100]
# Generator_loss:1.8134
# L1_loss:0.0867
# Discriminator_loss:0.4148
#
# EPOCH[153] - STEP[200]
# Generator_loss:2.7102
# L1_loss:0.1028
# Discriminator_loss:0.1530
#
# EPOCH[154] - STEP[100]
# Generator_loss:3.5944
# L1_loss:0.1304
# Discriminator_loss:0.3044
#
# EPOCH[154] - STEP[200]
# Generator_loss:4.2225
# L1_loss:0.1326
# Discriminator_loss:0.0697
#
# EPOCH[155] - STEP[100]
# Generator_loss:5.6658
# L1_loss:0.0927
# Discriminator_loss:0.3755
#
# EPOCH[155] - STEP[200]
# Generator_loss:5.3507
# L1_loss:0.1351
# Discriminator_loss:0.9519
#
# EPOCH[156] - STEP[100]
# Generator_loss:1.6824
# L1_loss:0.1272
# Discriminator_loss:0.3655
#
# EPOCH[156] - STEP[200]
# Generator_loss:1.7711
# L1_loss:0.1175
# Discriminator_loss:0.3824
#
# EPOCH[157] - STEP[100]
# Generator_loss:1.3753
# L1_loss:0.1501
# Discriminator_loss:0.5743
#
# EPOCH[157] - STEP[200]
# Generator_loss:4.9766
# L1_loss:0.1333
# Discriminator_loss:0.1687
#
# EPOCH[158] - STEP[100]
# Generator_loss:6.8459
# L1_loss:0.1579
# Discriminator_loss:0.0244
#
# EPOCH[158] - STEP[200]
# Generator_loss:2.7969
# L1_loss:0.1272
# Discriminator_loss:0.1104
#
# EPOCH[159] - STEP[100]
# Generator_loss:4.2571
# L1_loss:0.1231
# Discriminator_loss:0.0478
#
# EPOCH[159] - STEP[200]
# Generator_loss:4.8584
# L1_loss:0.1089
# Discriminator_loss:0.1145
#
# EPOCH[160] - STEP[100]
# Generator_loss:4.6318
# L1_loss:0.1169
# Discriminator_loss:0.0335
#
# EPOCH[160] - STEP[200]
# Generator_loss:5.9512
# L1_loss:0.1064
# Discriminator_loss:0.7452
#
# EPOCH[161] - STEP[100]
# Generator_loss:2.7498
# L1_loss:0.1189
# Discriminator_loss:0.2052
#
# EPOCH[161] - STEP[200]
# Generator_loss:6.5702
# L1_loss:0.1552
# Discriminator_loss:0.0935
#
# EPOCH[162] - STEP[100]
# Generator_loss:3.0224
# L1_loss:0.1506
# Discriminator_loss:0.0901
#
# EPOCH[162] - STEP[200]
# Generator_loss:5.7998
# L1_loss:0.1295
# Discriminator_loss:0.0231
#
# EPOCH[163] - STEP[100]
# Generator_loss:1.9285
# L1_loss:0.1433
# Discriminator_loss:0.7485
#
# EPOCH[163] - STEP[200]
# Generator_loss:5.4045
# L1_loss:0.1120
# Discriminator_loss:0.0104
#
# EPOCH[164] - STEP[100]
# Generator_loss:3.9005
# L1_loss:0.1209
# Discriminator_loss:0.1694
#
# EPOCH[164] - STEP[200]
# Generator_loss:1.8584
# L1_loss:0.1316
# Discriminator_loss:0.3361
#
# EPOCH[165] - STEP[100]
# Generator_loss:5.7598
# L1_loss:0.1366
# Discriminator_loss:0.0290
#
# EPOCH[165] - STEP[200]
# Generator_loss:2.4604
# L1_loss:0.1530
# Discriminator_loss:0.4693
#
# EPOCH[166] - STEP[100]
# Generator_loss:2.3627
# L1_loss:0.1038
# Discriminator_loss:0.2193
# EPOCH[166] - STEP[200]
# Generator_loss:4.5390
# L1_loss:0.1177
# Discriminator_loss:0.2298
#
# EPOCH[167] - STEP[100]
# Generator_loss:4.4377
# L1_loss:0.1243
# Discriminator_loss:0.1301
#
# EPOCH[167] - STEP[200]
# Generator_loss:5.2400
# L1_loss:0.1207
# Discriminator_loss:0.7454
#
# EPOCH[168] - STEP[100]
# Generator_loss:7.5071
# L1_loss:0.1343
# Discriminator_loss:0.1014
#
# EPOCH[168] - STEP[200]
# Generator_loss:3.6640
# L1_loss:0.1203
# Discriminator_loss:0.0874
#
# EPOCH[169] - STEP[100]
# Generator_loss:5.6705
# L1_loss:0.0821
# Discriminator_loss:4.5677
#
# EPOCH[169] - STEP[200]
# Generator_loss:4.5695
# L1_loss:0.1067
# Discriminator_loss:0.3023
#
# EPOCH[170] - STEP[100]
# Generator_loss:3.2078
# L1_loss:0.1166
# Discriminator_loss:0.2933
#
# EPOCH[170] - STEP[200]
# Generator_loss:5.7692
# L1_loss:0.1442
# Discriminator_loss:0.0184
#
# EPOCH[171] - STEP[100]
# Generator_loss:1.1785
# L1_loss:0.1223
# Discriminator_loss:1.2538
#
# EPOCH[171] - STEP[200]
# Generator_loss:5.8138
# L1_loss:0.1289
# Discriminator_loss:0.4039
#
# EPOCH[172] - STEP[100]
# Generator_loss:5.7941
# L1_loss:0.1238
# Discriminator_loss:0.3463
#
# EPOCH[172] - STEP[200]
# Generator_loss:1.3522
# L1_loss:0.1245
# Discriminator_loss:0.4723
#
# EPOCH[173] - STEP[100]
# Generator_loss:3.0394
# L1_loss:0.1025
# Discriminator_loss:0.1159
#
# EPOCH[173] - STEP[200]
# Generator_loss:2.6971
# L1_loss:0.1006
# Discriminator_loss:2.3425
#
# EPOCH[174] - STEP[100]
# Generator_loss:4.9384
# L1_loss:0.1589
# Discriminator_loss:0.0270
#
# EPOCH[174] - STEP[200]
# Generator_loss:6.5428
# L1_loss:0.1263
# Discriminator_loss:1.6216
#
# EPOCH[175] - STEP[100]
# Generator_loss:6.1325
# L1_loss:0.1548
# Discriminator_loss:0.2385
#
# EPOCH[175] - STEP[200]
# Generator_loss:1.2379
# L1_loss:0.1111
# Discriminator_loss:0.7787
#
# EPOCH[176] - STEP[100]
# Generator_loss:5.8199
# L1_loss:0.1007
# Discriminator_loss:0.0792
#
# EPOCH[176] - STEP[200]
# Generator_loss:3.4872
# L1_loss:0.1315
# Discriminator_loss:0.0550
#
# EPOCH[177] - STEP[100]
# Generator_loss:7.1058
# L1_loss:0.1305
# Discriminator_loss:0.0443
#
# EPOCH[177] - STEP[200]
# Generator_loss:4.0785
# L1_loss:0.1027
# Discriminator_loss:0.2329
#
# EPOCH[178] - STEP[100]
# Generator_loss:3.2873
# L1_loss:0.1197
# Discriminator_loss:0.1010
#
# EPOCH[178] - STEP[200]
# Generator_loss:5.4178
# L1_loss:0.1179
# Discriminator_loss:0.0240
#
# EPOCH[179] - STEP[100]
# Generator_loss:1.7838
# L1_loss:0.1278
# Discriminator_loss:0.4138
#
# EPOCH[179] - STEP[200]
# Generator_loss:6.0932
# L1_loss:0.1156
# Discriminator_loss:0.0096
#
# EPOCH[180] - STEP[100]
# Generator_loss:5.8658
# L1_loss:0.1158
# Discriminator_loss:0.1146
#
# EPOCH[180] - STEP[200]
# Generator_loss:3.4614
# L1_loss:0.1243
# Discriminator_loss:0.0828
#
# EPOCH[181] - STEP[100]
# Generator_loss:6.0725
# L1_loss:0.1227
# Discriminator_loss:0.4147
#
# EPOCH[181] - STEP[200]
# Generator_loss:3.0590
# L1_loss:0.1300
# Discriminator_loss:0.1647
#
# EPOCH[182] - STEP[100]
# Generator_loss:4.7525
# L1_loss:0.1056
# Discriminator_loss:0.4117
#
# EPOCH[182] - STEP[200]
# Generator_loss:4.3127
# L1_loss:0.1337
# Discriminator_loss:0.0686
#
# EPOCH[183] - STEP[100]
# Generator_loss:5.6775
# L1_loss:0.1096
# Discriminator_loss:0.2345
#
# EPOCH[183] - STEP[200]
# Generator_loss:2.2363
# L1_loss:0.1249
# Discriminator_loss:0.5653
#
# EPOCH[184] - STEP[100]
# Generator_loss:3.2491
# L1_loss:0.1126
# Discriminator_loss:0.1705
#
# EPOCH[184] - STEP[200]
# Generator_loss:3.1391
# L1_loss:0.1046
# Discriminator_loss:0.0786
#
# EPOCH[185] - STEP[100]
# Generator_loss:5.1513
# L1_loss:0.1157
# Discriminator_loss:0.4910
#
# EPOCH[185] - STEP[200]
# Generator_loss:3.9688
# L1_loss:0.1103
# Discriminator_loss:0.1865
#
# EPOCH[186] - STEP[100]
# Generator_loss:1.7300
# L1_loss:0.1074
# Discriminator_loss:0.5013
#
# EPOCH[186] - STEP[200]
# Generator_loss:2.2959
# L1_loss:0.1227
# Discriminator_loss:0.2458
#
# EPOCH[187] - STEP[100]
# Generator_loss:1.3453
# L1_loss:0.1402
# Discriminator_loss:0.7214
#
# EPOCH[187] - STEP[200]
# Generator_loss:1.0578
# L1_loss:0.1085
# Discriminator_loss:0.9223
#
# EPOCH[188] - STEP[100]
# Generator_loss:4.3632
# L1_loss:0.1014
# Discriminator_loss:2.3947
#
# EPOCH[188] - STEP[200]
# Generator_loss:5.5556
# L1_loss:0.1095
# Discriminator_loss:0.0177
#
# EPOCH[189] - STEP[100]
# Generator_loss:8.5400
# L1_loss:0.1338
# Discriminator_loss:0.1958
#
# EPOCH[189] - STEP[200]
# Generator_loss:3.2861
# L1_loss:0.1165
# Discriminator_loss:0.2717
#
# EPOCH[190] - STEP[100]
# Generator_loss:4.0472
# L1_loss:0.1392
# Discriminator_loss:0.1036
#
# EPOCH[190] - STEP[200]
# Generator_loss:4.9728
# L1_loss:0.1476
# Discriminator_loss:0.1743
#
# EPOCH[191] - STEP[100]
# Generator_loss:1.1438
# L1_loss:0.1127
# Discriminator_loss:0.6722
#
# EPOCH[191] - STEP[200]
# Generator_loss:4.2826
# L1_loss:0.1477
# Discriminator_loss:0.0362
#
# EPOCH[192] - STEP[100]
# Generator_loss:4.2766
# L1_loss:0.1005
# Discriminator_loss:0.3683
#
# EPOCH[192] - STEP[200]
# Generator_loss:3.1941
# L1_loss:0.1079
# Discriminator_loss:0.3140
#
# EPOCH[193] - STEP[100]
# Generator_loss:1.8921
# L1_loss:0.1365
# Discriminator_loss:1.0257
#
# EPOCH[193] - STEP[200]
# Generator_loss:2.8939
# L1_loss:0.1383
# Discriminator_loss:0.2903
# EPOCH[194] - STEP[100]
# Generator_loss:2.4506
# L1_loss:0.1261
# Discriminator_loss:0.1795
#
# EPOCH[194] - STEP[200]
# Generator_loss:8.4927
# L1_loss:0.1081
# Discriminator_loss:2.0594
#
# EPOCH[195] - STEP[100]
# Generator_loss:5.7814
# L1_loss:0.1067
# Discriminator_loss:0.1787
#
# EPOCH[195] - STEP[200]
# Generator_loss:2.7287
# L1_loss:0.1238
# Discriminator_loss:0.2561
#
# EPOCH[196] - STEP[100]
# Generator_loss:1.8941
# L1_loss:0.1044
# Discriminator_loss:0.3083
#
# EPOCH[196] - STEP[200]
# Generator_loss:6.4583
# L1_loss:0.1095
# Discriminator_loss:0.0653
#
# EPOCH[197] - STEP[100]
# Generator_loss:4.3922
# L1_loss:0.1436
# Discriminator_loss:0.0417
#
# EPOCH[197] - STEP[200]
# Generator_loss:4.8326
# L1_loss:0.1215
# Discriminator_loss:0.1647
#
# EPOCH[198] - STEP[100]
# Generator_loss:0.7270
# L1_loss:0.1099
# Discriminator_loss:1.3027
#
# EPOCH[198] - STEP[200]
# Generator_loss:5.5882
# L1_loss:0.1000
# Discriminator_loss:0.7025
#
# EPOCH[199] - STEP[100]
# Generator_loss:4.4875
# L1_loss:0.1181
# Discriminator_loss:0.2517
#
# EPOCH[199] - STEP[200]
# Generator_loss:5.4941
# L1_loss:0.1102
# Discriminator_loss:0.6198
#
# EPOCH[200] - STEP[100]
# Generator_loss:3.7390
# L1_loss:0.1071
# Discriminator_loss:0.6967
#
# EPOCH[200] - STEP[200]
# Generator_loss:4.7470
# L1_loss:0.1145
# Discriminator_loss:0.0828

# %%
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))
